# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/User/Desktop/디지털하나로/CardData_new.csv',encoding='cp949')
df
# Out:
#             회원번호  남녀구분코드  연령  소지여부_신용   입회일자_신용  입회경과개월수_신용  탈회여부  회원여부_연체  \
# 0       YNtSN9Oa       2  64        1  20140709          54     1        0
# 1       Rijqdlzu       1  24        1  20170412          21     0        0
# 2       NOsf3TZS       2  43        1  20170426          21     1        0
# 3       7IPZGTZu       2  79        1  20141128          50     0        0
# 4       pEEsUF2u       2  82        1  20120905          76     0        0
# ...          ...     ...  ..      ...       ...         ...   ...      ...
# 299995  Gso9Jlid       2  47        1  20170630          18     0        0
# 299996  EDQYlTTX       2  69        1  20150417          45     0        0
# 299997  82GwFS1D       1  36        1  20120608          79     0        0
# 299998  LUYeNjki       1  48        1  20120508          80     1        0
# 299999  bnKXePYO       2  36        1  20180222          11     1        0
#
# ...

# %%
df.columns
# Out:
# Index(['회원번호', '남녀구분코드', '연령', '소지여부_신용', '입회일자_신용', '입회경과개월수_신용', '탈회여부',
#        '회원여부_연체', '수신거부여부_TM', '수신거부여부_DM',
#        ...
#        '캠페인접촉건수_R12M', '캠페인접촉일수_R12M', '캠페인접촉월수_R12M', '접촉후경과월_R12M',
#        '보험콜대상월수_R12M', '보험콜대상횟수_R12M', '보험콜통화횟수_R12M', '보험콜배정후경과월_R12M',
#        '보험콜통화후경과월_R12M', '고객구분'],
#       dtype='object', length=302)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Columns: 302 entries, 회원번호 to 고객구분
# dtypes: int64(290), object(12)
# memory usage: 691.2+ MB

# %%
df.describe()
# Out:
#               남녀구분코드             연령        소지여부_신용       입회일자_신용  \
# count  300000.000000  300000.000000  300000.000000  3.000000e+05
# mean        1.473560      46.212110       0.979740  2.011614e+07
# std         0.499301      12.087588       0.140889  7.454927e+04
# min         1.000000      19.000000       0.000000  1.010100e+04
# 25%         1.000000      37.000000       1.000000  2.009013e+07
# 50%         1.000000      46.000000       1.000000  2.014011e+07
# 75%         2.000000      54.000000       1.000000  2.017023e+07
# max         2.000000      98.000000       1.000000  2.018063e+07
#
#          입회경과개월수_신용           탈회여부        회원여부_연체      수신거부여부_TM  \
# count  300000.00000  300000.000000  300000.000000  300000.000000
# mean       83.97931       0.406513       0.013010       0.379863
# std        77.67084       0.491183       0.113317       0.485353
# min         0.00000       0.000000       0.000000       0.000000
# ...

# %%
df['BL여부_R12M'].value_counts()
# Out:
# 0    295761
# 1      4239
# Name: BL여부_R12M, dtype: int64

# %%
df['직장시군구명'].value_counts()
# Out:
# 중구      13237
# 강남구     12748
# 서구       7806
# 서초구      7150
# 성남시      6772
#         ...
# 울릉군        16
# 영양군        15
# 청원군         1
# 북제주군        1
# 여주군         1
# Name: 직장시군구명, Length: 209, dtype: int64

# %%
sns.countplot(x='직장시군구명',data=df)
# Out:
# <Axes: xlabel='직장시군구명', ylabel='count'>
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52285 (\N{HANGUL SYLLABLE CANG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46993 (\N{HANGUL SYLLABLE RANG}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
df['고객구분'].value_counts()
# Out:
# 21.Active_연속    222863
# 22.Active_간헐     29035
# 34.휴면_9M+        26974
# 32.휴면_6M-         8951
# 33.휴면_9M-         7638
# 31.휴면_3M          4539
# Name: 고객구분, dtype: int64

# %%
df['탈회여부'].value_counts()
# Out:
# 0    178046
# 1    121954
# Name: 탈회여부, dtype: int64

# %%
df['자격기준'].value_counts()
# Out:
# 06.기업체     79838
# 08.은행거래    78590
# 11.자영업자    62562
# 01.공무원     16083
# 02.교육기관    11310
# 04.의료기관    10215
# 12.체크전환    10166
# 99.기타       8921
# 10.배우자      7241
# 03.금융기관     6299
# 07.소기업      6284
# 09.전문직      1785
# 05.언론기관      706
# Name: 자격기준, dtype: int64

# %%
df['고객구분'].value_counts()
# Out:
# 21.Active_연속    222863
# 22.Active_간헐     29035
# 34.휴면_9M+        26974
# 32.휴면_6M-         8951
# 33.휴면_9M-         7638
# 31.휴면_3M          4539
# Name: 고객구분, dtype: int64

# %%
df['이용금액대'].value_counts()
# Out:
# 01.100만원+    61467
# 05.10만원-     59192
# 02.50만원+     54216
# 09.미사용       48480
# 03.30만원+     39667
# 04.10만원+     36978
# Name: 이용금액대, dtype: int64

# %%
#age 칼럼 분포 확인
import seaborn as sns
sns.displot(data=df, x='연령', kind='kde')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df['Life_Stage'].value_counts()
# Out:
# 4.자녀성장기(1)    99160
# 5.자녀성장기(2)    74692
# 3.자녀출산기       30693
# 2.가족형성기       29736
# 7.노령          29532
# 6.자녀출가기       25365
# 1.Single      10822
# Name: Life_Stage, dtype: int64

# %%
df['자격구분상세'].value_counts()
# Out:
# 08.은행거래_수신평잔                    61493
# 10.부동산보유                        35972
# 06.기업체_개인사업체임의단체연소득2.4천이상       24937
# 99.기타                           23101
# 06.기업체_납입자본금3억이상중소기업            20110
# 06.기업체_30대그룹계열사및상장법인            19073
# 06.기업체_납입자본금3억미만중소기업            13111
# 07.소기업                          12213
# 13.체크전환                         10166
# 01.공무원_일반                        8230
# 08.은행거래_부동산담보대출                  7925
# 11.배우자                           7241
# 01.공무원_정부투자공공기관                  6673
# 08.은행거래_신용대출                     6179
# 02.교육기관_초중고교사                    4840
# 04.의료기관_의료관련면허소시자                4113
# 04.의료기관                          3207
# 00.SK제휴사                         3099
# 14.사업소득                          3052
# 04.의료기관_의사약사한의사                  2895
# 03.금융기관_은행증권보험은행연합회              2662
# 06.기업체_코스닥등록기업                   2043
# 08.은행거래_급여이체                     2019
# 02.교육기관_유치원어린이집                  1869
# 00.하나카드및관계사                      1544
# ...

# %%
df['자격기준'].value_counts()
# Out:
# 06.기업체     79838
# 08.은행거래    78590
# 11.자영업자    62562
# 01.공무원     16083
# 02.교육기관    11310
# 04.의료기관    10215
# 12.체크전환    10166
# 99.기타       8921
# 10.배우자      7241
# 03.금융기관     6299
# 07.소기업      6284
# 09.전문직      1785
# 05.언론기관      706
# Name: 자격기준, dtype: int64

# %%
a = df.groupby(['연령', 'Life_Stage']).size().unstack()
a
# Out:
# Life_Stage  1.Single  2.가족형성기  3.자녀출산기  4.자녀성장기(1)  5.자녀성장기(2)  6.자녀출가기   7.노령
# 연령
# 19               3.0      4.0      7.0        19.0        10.0      8.0    7.0
# 20               8.0     24.0     15.0        73.0        70.0     20.0   29.0
# 21              18.0     50.0     41.0       156.0       128.0     42.0   44.0
# 22              27.0     82.0     83.0       283.0       184.0     71.0   70.0
# 23              38.0    129.0    118.0       390.0       326.0     88.0  127.0
# ..               ...      ...      ...         ...         ...      ...    ...
# 93               NaN      NaN      1.0         3.0         3.0      NaN    1.0
# 94               1.0      NaN      1.0         1.0         NaN      NaN    1.0
# 95               NaN      NaN      1.0         2.0         1.0      1.0    NaN
# 96               NaN      NaN      NaN         NaN         1.0      NaN    NaN
# 98               NaN      1.0      NaN         NaN         2.0      NaN    NaN
#
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
z=df[df['자격기준']=='11.자영업자']
z
# Out:
#             회원번호  남녀구분코드  연령  소지여부_신용   입회일자_신용  입회경과개월수_신용  탈회여부  회원여부_연체  \
# 0       YNtSN9Oa       2  64        1  20140709          54     1        0
# 1       Rijqdlzu       1  24        1  20170412          21     0        0
# 4       pEEsUF2u       2  82        1  20120905          76     0        0
# 5       mrILBIsf       1  38        1  20180201          11     0        0
# 6       w8NeFjRo       2  38        1  20170609          19     1        0
# ...          ...     ...  ..      ...       ...         ...   ...      ...
# 299969  9lMcu2Me       1  46        1  20180510           8     0        0
# 299973  vLr2WWME       1  43        1  20171012          15     1        0
# 299985  1KuXiNPJ       2  27        1  20140926          52     0        0
# 299987  bckuR3dZ       1  28        1  20140305          58     1        0
# 299999  bnKXePYO       2  36        1  20180222          11     1        0
#
# ...

# %%
df.groupby('자격기준')['이용금액_R3M_신용체크'].mean().sort_values(ascending=False)
# Out:
# 자격기준
# 99.기타      6.110288e+06
# 04.의료기관    3.435398e+06
# 03.금융기관    3.112039e+06
# 09.전문직     3.015343e+06
# 12.체크전환    2.488663e+06
# 05.언론기관    2.408050e+06
# 07.소기업     2.384666e+06
# 08.은행거래    2.283565e+06
# 06.기업체     2.159199e+06
# 02.교육기관    2.032283e+06
# 01.공무원     1.846204e+06
# 11.자영업자    1.702359e+06
# 10.배우자     1.685351e+06
# Name: 이용금액_R3M_신용체크, dtype: float64

# %%
df.groupby('자격구분상세')['이용금액_R3M_신용체크'].mean().sort_values(ascending=False)
# Out:
# 자격구분상세
# 00.SK제휴사                        9.084598e+06
# 04.의료기관_의사약사한의사                 6.657885e+06
# 00.하나카드및관계사                     5.812268e+06
# 09.전문직_변호사변리사                   4.412520e+06
# 08.은행거래_수신평잔3천이상                4.382549e+06
# 09.전문직_공인회계사기술사건축사세무사           3.936985e+06
# 03.금융기관                         3.845527e+06
# 09.전문직_손해사정인법무사노무사통역사행정사보험계리    3.609345e+06
# 12.자영업자                         2.795797e+06
# 08.은행거래                         2.765306e+06
# 02.교육기관_대학교교원                   2.718073e+06
# 06.기업체                          2.667094e+06
# 08.은행거래_신용대출                    2.601232e+06
# 99.기타                           2.596422e+06
# 08.은행거래_급여이체                    2.573119e+06
# 03.금융기관_여신전문금융기관                2.530282e+06
# 02.교육기관_학술연구단체                  2.506493e+06
# 13.체크전환                         2.488663e+06
# 06.기업체_30대그룹계열사및상장법인            2.484013e+06
# 06.기업체_코스닥등록기업                  2.427411e+06
# 01.공무원_군인                       2.412464e+06
# ...
